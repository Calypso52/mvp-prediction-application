# %%
from pyspark.sql import SparkSession
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pyspark.sql
import sys
from pyspark.sql.functions import lit
# spark.version

# %%
spark.version
# Out:
# '3.1.2'

# %%
spark = SparkSession.builder.appName("mvp-prediction").getOrCreate()
print('spark session created')
# Out:
# spark session created

# %% [markdown]
# 1. Data loading

# %%
data_paths = ['gs://6893-data/triLabel/player_stats_2018_2019.csv',
              'gs://6893-data/triLabel/player_stats_2019_2020.csv', 
              'gs://6893-data/triLabel/player_stats_2020_2021.csv',
              'gs://6893-data/triLabel/player_stats_2021_2022.csv'
]
data_1 = spark.read.format("csv").option("header", "true").option("inferschema", "true").load(data_paths[0])
data_2 = spark.read.format("csv").option("header", "true").option("inferschema", "true").load(data_paths[1])
data_3 = spark.read.format("csv").option("header", "true").option("inferschema", "true").load(data_paths[2])

data = data_1.union(data_2)
data = data.union(data_3)
ongoing_data = spark.read.format("csv").option("header", "true").option("inferschema", "true").load(data_paths[3])
# print(data)

# %%
print('Overall shape of data', data.count(), len(data.columns))
print('2018-2019 dimension of data', data_1.count(), len(data_1.columns))
print('2019-2020 dimension of data', data_2.count(), len(data_2.columns))
print('2020-2021 dimension of data', data_3.count(), len(data_3.columns))
# Out:
# Overall shape of data 1599 11
# 2018-2019 dimension of data 530 11
# 2019-2020 dimension of data 529 11
# 2020-2021 dimension of data 540 11

# %%
mip_datapaths = [
             'gs://6893-data/mipData/player_improvement_2019_2020.csv',
             'gs://6893-data/mipData/player_improvement_2020_2021.csv',
             'gs://6893-data/mipData/player_improvement_2021_2022.csv'
]
mip_data_1 = spark.read.format("csv").option("header", "true").option("inferschema", "true").load(mip_datapaths[0])
mip_data_2 = spark.read.format("csv").option("header", "true").option("inferschema", "true").load(mip_datapaths[1])

mip_data = mip_data_1.union(mip_data_2)
ongoing_mip_data = spark.read.format("csv").option("header", "true").option("inferschema", "true").load(mip_datapaths[2])

# %%
print('Overall shape of data', mip_data.count(), len(mip_data.columns))
print('2019~2020 dimension of data', mip_data_1.count(), len(mip_data_1.columns))
print('2020~2021 dimension of data', mip_data_2.count(), len(mip_data_2.columns))
print('2021~2022 dimension of data', ongoing_mip_data.count(), len(ongoing_mip_data.columns))
print(mip_data)
# Out:
# Overall shape of data 811 7
# 2019~2020 dimension of data 400 7
# 2020~2021 dimension of data 411 7
# 2021~2022 dimension of data 369 7
# DataFrame[reb: double, ast: double, stl: double, blk: double, tov: double, pts: double, label: int]

# %% [markdown]
# 2. Data preprocessing

# %%
from pyspark.ml import Pipeline
from pyspark.ml.feature import OneHotEncoder, StringIndexer, VectorAssembler

# %%
#stages in our Pipeline
stages = []

# %%
# Transform all features into a vector using VectorAssembler
numericCols = ["reb", "ast", "stl", "blk", "tov", "pts"]
assemblerInputs = numericCols
assembler = VectorAssembler(inputCols=assemblerInputs, outputCol="features")
stages += [assembler]

# %%
pipeline = Pipeline(stages=stages)
pipelineModel = pipeline.fit(data)
preppedDataDF = pipelineModel.transform(data)
preppedOngoingDF = pipelineModel.transform(ongoing_data)

# %%
pipelineModelMip = pipeline.fit(mip_data)
preppedDataMip = pipelineModelMip.transform(mip_data)
preppedOngoingMip = pipelineModelMip.transform(ongoing_mip_data)
preppedDataMip.take(3)
# preppedOngoingMip.take(3)
# Out:
# [Row(reb=-0.021419168986074526, ast=0.49997688444709554, stl=-0.4428101732219239, blk=0.09920308478640266, tov=-0.15635161427385222, pts=-0.2329237762816053, label=0, features=DenseVector([-0.0214, 0.5, -0.4428, 0.0992, -0.1564, -0.2329])),
#  Row(reb=0.4085906755386262, ast=1.285148252475082, stl=0.32403712897915865, blk=0.5999857562190266, tov=0.8320552891480542, pts=0.7518776711044055, label=1, features=DenseVector([0.4086, 1.2851, 0.324, 0.6, 0.8321, 0.7519])),
#  Row(reb=-0.19106129091453897, ast=0.01954522067931028, stl=0.2879691836603197, blk=0.22014566525875912, tov=-0.25062815521712517, pts=-0.13319366185627537, label=0, features=DenseVector([-0.1911, 0.0195, 0.288, 0.2201, -0.2506, -0.1332]))]

# %%
preppedDataDF.take(3)
preppedOngoingDF.take(3)
# Out:
# [Row(id='84b7ddae-180a-464f-9962-2c3b3222810c', name='Precious Achiuwa', reb=8.125, ast=1.625, stl=0.5625, blk=0.625, tov=1.0, pts=8.25, src='https://cdn.nba.com/headshots/nba/latest/260x190/1630173.png', teamSrc='https://cdn.nba.com/logos/nba/1610612761/primary/L/logo.svg', team='Toronto Raptors', newsUrl=None, newsTitle=None, newsDate=None, newsIntro=None, features=DenseVector([8.125, 1.625, 0.5625, 0.625, 1.0, 8.25])),
#  Row(id='090e9e99-10df-4aaf-b1ff-2645a8420aa5', name='Steven Adams', reb=8.111111111, ast=2.777777778, stl=0.833333333, blk=0.722222222, tov=1.5, pts=7.0, src='https://cdn.nba.com/headshots/nba/latest/260x190/203500.png', teamSrc='https://cdn.nba.com/logos/nba/1610612763/primary/L/logo.svg', team='Memphis Grizzlies', newsUrl=None, newsTitle=None, newsDate=None, newsIntro=None, features=DenseVector([8.1111, 2.7778, 0.8333, 0.7222, 1.5, 7.0])),
#  Row(id='100b9996-96db-4e10-b29b-e449d2413d95', name='Bam Adebayo', reb=10.1875, ast=2.8125, stl=1.1875, blk=0.375, tov=2.9375, pts=19.0, src='https://cdn.nba.com/headshots/nba/latest/260x190/1628389.png', teamSrc='https://cdn.nba.com/logos/nba/1610612748/primary/L/logo.svg', team='Miami Heat', newsUrl=None, newsTitle=None, newsDate=None, newsIntro=None, features=DenseVector([10.1875, 2.8125, 1.1875, 0.375, 2.9375, 19.0]))]

# %%
# Keep relevant columns

cols = data.columns
selectedcols = ["features"] + cols
dataset = preppedDataDF.select(selectedcols)

ongoing_dataset = preppedOngoingDF.select(['features', 'id', 'name', 'reb', 'ast', 'stl', 'blk', 'tov', 'pts'])

display(dataset)
display(ongoing_dataset)
# Out:
# DataFrame[features: vector, id: string, name: string, mvpLabel: int, mipLabel: int, dpoyLabel: int, reb: double, ast: double, stl: double, blk: double, tov: double, pts: double]
# DataFrame[features: vector, id: string, name: string, reb: double, ast: double, stl: double, blk: double, tov: double, pts: double]

# %%
print(selectedcols)
print(ongoing_dataset.count())
# Out:
# ['features', 'id', 'name', 'mvpLabel', 'mipLabel', 'dpoyLabel', 'reb', 'ast', 'stl', 'blk', 'tov', 'pts']
# 466

# %%
dataset_mip = preppedDataMip.select(['features','label', 'reb', 'ast', 'stl', 'blk', 'tov', 'pts'])
# dataset_mip.show(300)
dataset_ongoing_mip = preppedOngoingMip.select(['features', 'name', 'reb', 'ast', 'stl', 'blk', 'tov', 'pts'])
display(dataset_mip)
display(dataset_ongoing_mip)
# Out:
# DataFrame[features: vector, label: int, reb: double, ast: double, stl: double, blk: double, tov: double, pts: double]
# DataFrame[features: vector, name: string, reb: double, ast: double, stl: double, blk: double, tov: double, pts:
# |[0.75189063804787...|    0|  0.7518906380478787| 0.10896421757329855|  1.8272545358598784|  1.7501825472594392| 0.30467851196463397|  0.8819799662683698|
# |[0.77119028289102...|    0|  0.7711902828910203|   0.788740078924241|  0.5754297033529475|    1.31099515677477|  0.2134612925015769|  1.5276921021187484|
# |[0.93909966344646...|    0|  0.9390996634464678|  0.5097530641106152|  0.9461427772984576|   2.670197701912254|-0.46461558149267596| 0.24344938511564546|
# |[1.15815182797134...|    0|  1.1581518279713459| 0.22803001504385045|  1.5686467942443845|-0.17408604765932936|-0.04916841849707528|  0.6544716351813127|
# |[1.86245206106823...|    0|  1.8624520610682336|  1.7271049668972183|  0.8736246349813398|   5.693892934878946|  2.4170290389117772|  1.1103745062754196|
# |[2.38710831983377...|    0|  2.3871083198337715|  1.9324241582629005|  11426.706671909276|                 0.0|  11087.830654437324|   1.037553595083269|
# |[4.00074876058698...|    0|   4.000748760586988|  10.834764008422184|                 0.0|                 0.0|                 0.0|   17.14169767442887|
# +--------------------+-----+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+

# %% [markdown]
# 3. Modeling

# %%
from pyspark.ml.classification import LogisticRegression, RandomForestClassifier
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

# %%
import datetime
from pytz import timezone
tz = timezone('EST')
now = datetime.datetime.now(tz)

# Fit model to prepped data

#LogisticRegression model, maxIter=10
#=====your code here============
lrModel_mvp = LogisticRegression(featuresCol="features", labelCol="mvpLabel", maxIter=10).fit(trainingData)
lrModel_dpoy = LogisticRegression(featuresCol="features", labelCol="dpoyLabel", maxIter=10).fit(trainingData)
lrModel_mip = LogisticRegression(featuresCol="features", labelCol="label", maxIter=10).fit(trainingData_mip)
#===============================

mvp_predictions = lrModel_mvp.transform(testData)
dpoy_predictions = lrModel_dpoy.transform(testData)
mip_predictions = lrModel_mip.transform(testData_mip)

# compute accuracy on the test set
evaluator = MulticlassClassificationEvaluator(labelCol="mvpLabel", predictionCol="prediction", metricName="accuracy")
accuracy = evaluator.evaluate(mvp_predictions)
print("Test set accuracy for mvp prediction = " + str(accuracy))
evaluator = MulticlassClassificationEvaluator(labelCol="dpoyLabel", predictionCol="prediction", metricName="accuracy")
accuracy = evaluator.evaluate(dpoy_predictions)
print("Test set accuracy for dpoy prediction = " + str(accuracy))
evaluator = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="accuracy")
accuracy = evaluator.evaluate(mip_predictions)
print("Test set accuracy for mip prediction = " + str(accuracy))

mvp_predictions = lrModel_mvp.transform(ongoing_dataset)
mvp_selected = mvp_predictions.select(['id', 'name', 'probability'])
mvp_selected = mvp_selected.withColumnRenamed('probability', 'mvp_prediction').withColumn('date', lit(str(now)[:10]))

# mvp_selected.show(mvp_selected.count(), False)

dpoy_predictions = lrModel_dpoy.transform(ongoing_dataset)
dpoy_selected = dpoy_predictions.select(['id', 'name', 'probability'])
dpoy_selected = dpoy_selected.withColumnRenamed('probability', 'dpoy_prediction').withColumn('date', lit(str(now)[:10]))

mip_predictions = lrModel_mip.transform(dataset_ongoing_mip)
print(mip_predictions)
print('mip dataset ongoing')
dataset_ongoing_mip.show(5)
print('training dataset mip')
trainingData_mip.show(20)
mip_selected = mip_predictions.select(['name', 'probability', 'prediction'])
# mip_selected.show(mip_selected.count())
mip_selected = mip_selected.withColumnRenamed('probability', 'mip_prediction').withColumn('date', lit(str(now)[:10]))
# Out:
# Test set accuracy for mvp prediction = 0.9853372434017595
# Test set accuracy for dpoy prediction = 0.9765395894428153
# Test set accuracy for mip prediction = 0.9746835443037974
# DataFrame[features: vector, name: string, reb: double, ast: double, stl: double, blk: double, tov: double, pts: double, rawPrediction: vector, probability: vector, prediction: double]
# mip dataset ongoing
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------------+--------------------+
# |            features|                name|                 reb|                 ast|                 stl|                 blk|                tov|                 pts|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------------+--------------------+
# |[-0.5528189915733...|    0| -0.5528189915733625|-0.48241429939147756| 0.05478118991621371|  0.6766614468333627|-0.16390443227352244| -0.5281305205283171|
# |[-0.5477752051955...|    0| -0.5477752051955477|-0.39803149445376707| -0.7342386320425699|-0.25935009423655303| -0.5335135655791667| -0.6585718261741763|
# |[-0.4976884862617...|    0| -0.4976884862617237| -0.9999098368330605| -0.9998976165493176| -0.9999741527066774| -0.9999542297520474| -0.8723390867070491|
# |[-0.4976830706127...|    0| -0.4976830706127807| -0.6500060263783901| 0.05959828161776597|-0.01809755596025...|  -0.552729167992592| -0.6336878896650127|
# |[-0.4976758499308...|    0|-0.49767584993086156| -0.5986636384566959| -0.9999744021717338|                 0.0|   12507.33000376883| 0.05679507270321798|
# +--------------------+-----+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
print(now)
print(mvp_selected)
print(mvp_selected.count(), 'lines in mvp_prediction')
print(dpoy_selected)
print(dpoy_selected.count(), 'lines in dpoy_prediction')
print(mip_selected)
print(mip_selected.count(), 'lines in mip_prediction')

mvp_pd = mvp_selected.toPandas()
for idx, row in mvp_pd.iterrows():
    row.mvp_prediction = row.mvp_prediction[1]
    # print(row)
print(mvp_pd.head(3))
mvp_pd.to_csv('mvp_prediction_results.csv')

dpoy_pd = dpoy_selected.toPandas()
for idx, row in dpoy_pd.iterrows():
    row.dpoy_prediction = row.dpoy_prediction[1]
    # print(row)
print(dpoy_pd.head(3))
dpoy_pd.to_csv('dpoy_prediction_results.csv')

mip_pd = mip_selected.toPandas()
# print(mip_pd)
for idx, row in mip_pd.iterrows():
    row.mip_prediction = row.mip_prediction[1]
    # print(row)
print(mip_pd.head(3))
mip_pd.to_csv('mip_prediction_results.csv')
# Out:
# 2021-12-16 22:50:17.449223-05:00
# DataFrame[name: string, probability: vector, prediction: double, blk: double]
# 466 lines in mvp_prediction
# DataFrame[name: string, probability: vector, prediction: double, blk: double]
# 466 lines in dpoy_prediction
# DataFrame[name: string, probability: vector, prediction: double]
# 369 lines in mip_prediction
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_8180/1578236916.py in <module>
#       9 mvp_pd = mvp_selected.toPandas()
#      10 for idx, row in mvp_pd.iterrows():
# ---> 11     row.mvp_prediction = row.mvp_prediction[1]
#      12     # print(row)
#      13 print(mvp_pd.head(3))
#
# /opt/conda/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'mvp_prediction'

# %%
from pytz import timezone
tz = timezone('EST')
datetime.datetime.now(tz)
# Out:
# datetime.datetime(2021, 12, 16, 22, 30, 35, 962226, tzinfo=<StaticTzInfo 'EST'>)

# %%
import os
import sys
# os.getcwd()

# %%
from pyspark.ml.classification import RandomForestClassifier
# Random Forest
#=====your code here==========
rfModel_mvp = RandomForestClassifier(featuresCol="features", labelCol="mvpLabel").fit(trainingData)
rfModel_dpoy = RandomForestClassifier(featuresCol="features", labelCol="dpoyLabel").fit(trainingData)
rfModel_mip = RandomForestClassifier(featuresCol="features", labelCol="label").fit(trainingData_mip)
#===============================


mvp_predictions = rfModel_mvp.transform(testData)
dpoy_predictions = rfModel_dpoy.transform(testData)
mip_predictions = rfModel_mip.transform(testData_mip)
# compute accuracy on the test set
evaluator = MulticlassClassificationEvaluator(labelCol="mvpLabel", predictionCol="prediction", metricName="accuracy")
accuracy = evaluator.evaluate(mvp_predictions)
print("Test set accuracy for mvp prediction = " + str(accuracy))
evaluator = MulticlassClassificationEvaluator(labelCol="dpoyLabel", predictionCol="prediction", metricName="accuracy")
accuracy = evaluator.evaluate(dpoy_predictions)
print("Test set accuracy for dpoy prediction = " + str(accuracy))
evaluator = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="accuracy")
accuracy = evaluator.evaluate(mip_predictions)
print("Test set accuracy for mip prediction = " + str(accuracy))

mvp_predictions = rfModel_mvp.transform(ongoing_dataset)
mvp_selected = mvp_predictions.select(['name', 'probability', 'prediction', 'blk'])
# mvp_selected.show(mvp_selected.count(), False)

dpoy_predictions = rfModel_dpoy.transform(ongoing_dataset)
dpoy_selected = dpoy_predictions.select(['name', 'probability', 'prediction', 'blk'])
# dpoy_selected.show(dpoy_selected.count(), False)
print(dpoy_predictions)

mip_predictions = rfModel_mip.transform(dataset_ongoing_mip)
mip_selected = mip_predictions.select(['name', 'probability', 'prediction'])
# dpoy_selected.show(dpoy_selected.count(), False)
mip_selected.show(30)
# Out:
# Test set accuracy for mvp prediction = 0.9824046920821115
# Test set accuracy for dpoy prediction = 0.9706744868035191
# Test set accuracy for mip prediction = 0.9746835443037974
# DataFrame[features: vector, id: string, name: string, reb: double, ast: double, stl: double, blk: double, tov: double, pts: double, rawPrediction: vector, probability: vector, prediction: double]
# +--------------------+--------------------+----------+
# |                name|         probability|prediction|
# +--------------------+--------------------+----------+
# |    Precious Achiuwa|[0.93555651664983...|       0.0|
# |        Steven Adams|[0.99276932793234...|       0.0|
# |         Bam Adebayo|[0.78091346870495...|       0.0|
# |   LaMarcus Aldridge|[0.68944932849460...|       0.0|
# |Nickeil Alexander...|[0.78589958167306...|       0.0|
# |       Grayson Allen|[0.77375226218897...|       0.0|
# |       Jarrett Allen|[0.78395586100681...|       0.0|
# |       Kyle Anderson|[0.99895557013068...|       0.0|
# |Giannis Antetokou...|[0.99059572621580...|       0.0|
# |Thanasis Antetoko...|[0.88244749808926...|       0.0|
# |     Carmelo Anthony|[0.94690443610202...|       0.0|
# |        Cole Anthony|[0.79423037023305...|       0.0|
# |          OG Anunoby|[0.85530271102198...|       0.0|
# |       D.J. Augustin|[0.99895557013068...|       0.0|
# |         Deni Avdija|[0.96061358092265...|       0.0|
# |       Deandre Ayton|[0.72734552924166...|       0.0|
# |      Udoka Azubuike|[0.99697248127708...|       0.0|
# |       Marvin Bagley|[0.99891675776155...|       0.0|
# |         LaMelo Ball|[0.80720709665136...|       0.0|
# |          Lonzo Ball|[0.99536695936056...|       0.0|
# |       Mohamed Bamba|[0.91610160550913...|       0.0|
# |        Desmond Bane|[0.72852235015376...|       0.0|
# |     Harrison Barnes|[0.94324490944874...|       0.0|
# |          RJ Barrett|[0.99697248127708...|       0.0|
# |         Will Barton|[0.83191193808601...|       0.0|
# |    Keita Bates-Diop|[0.92912871963885...|       0.0|
# |       Nicolas Batum|[0.83815443610202...|       0.0|
# |       Kent Bazemore|[0.99891675776155...|       0.0|
# |       Darius Bazley|[0.94081738475216...|       0.0|
# |        Bradley Beal|[0.98701393224889...|       0.0|
# +--------------------+--------------------+----------+
# only showing top 30 rows

# %%
mip_selected = mip_selected.withColumnRenamed('probability', 'mip_prediction').withColumn('date', lit(str(now)[:10]))
mip_selected = mip_selected.select(['name', 'mip_prediction', 'date'])
mip_pd = mip_selected.toPandas()
# print(mip_pd)
for idx, row in mip_pd.iterrows():
    row.mip_prediction = row.mip_prediction[1]/0.35
    print(row)
print(mip_pd.head(3))
mip_pd.to_csv('mip_prediction_results.csv')
# Out:
# name              Precious Achiuwa
# mip_prediction            0.184124
# date                    2021-12-16
# Name: 0, dtype: object
# name              Steven Adams
# mip_prediction        0.020659
# date                2021-12-16
# Name: 1, dtype: object
# name              Bam Adebayo
# mip_prediction       0.625962
# date               2021-12-16
# Name: 2, dtype: object
# name              LaMarcus Aldridge
# mip_prediction             0.887288
# date                     2021-12-16
# Name: 3, dtype: object
# name              Nickeil Alexander-Walker
# mip_prediction                    0.611715
# date                            2021-12-16
# Name: 4, dtype: object
# name              Grayson Allen
# mip_prediction         0.646422
# date                 2021-12-16
# Name: 5, dtype: object
# name              Jarrett Allen
# mip_prediction         0.617269
# date                 2021-12-16
# Name: 6, dtype: object
# name              Kyle Anderson
# mip_prediction         0.002984
# date                 2021-12-16
# Name: 7, dtype: object
# name              Giannis Antetokounmpo
# mip_prediction                 0.026869
# date                         2021-12-16
# Name: 8, dtype: object
# name              Thanasis Antetokounmpo
# mip_prediction                  0.335864
# date                          2021-12-16
# Name: 9, dtype: object
# name              Carmelo Anthony
# mip_prediction           0.151702
# date                   2021-12-16
# Name: 10, dtype: object
# name              Cole Anthony
# mip_prediction        0.587913
# date                2021-12-16
# Name: 11, dtype: object
# name              OG Anunoby
# mip_prediction      0.413421
# date              2021-12-16
# Name: 12, dtype: object
# name              D.J. Augustin
# mip_prediction         0.002984
# date                 2021-12-16
# Name: 13, dtype: object
# name              Deni Avdija
# mip_prediction       0.112533
# date               2021-12-16
# Name: 14, dtype: object
# name              Deandre Ayton
# mip_prediction         0.779013
# date                 2021-12-16
# Name: 15, dtype: object
# name              Udoka Azubuike
# mip_prediction           0.00865
# date                  2021-12-16
# Name: 16, dtype: object
# name              Marvin Bagley
# mip_prediction         0.003095
# date                 2021-12-16
# Name: 17, dtype: object
# name              LaMelo Ball
# mip_prediction       0.550837
# date               2021-12-16
# Name: 18, dtype: object
# name              Lonzo Ball
# mip_prediction      0.013237
# date              2021-12-16
# Name: 19, dtype: object
# name              Mohamed Bamba
# mip_prediction          0.23971
# date                 2021-12-16
# Name: 20, dtype: object
# name              Desmond Bane
# mip_prediction         0.77565
# date                2021-12-16
# Name: 21, dtype: object
# name              Harrison Barnes
# mip_prediction           0.162157
# date                   2021-12-16
# Name: 22, dtype: object
# name              RJ Barrett
# mip_prediction       0.00865
# date              2021-12-16
# Name: 23, dtype: object
# name              Will Barton
# mip_prediction       0.480252
# date               2021-12-16
# Name: 24, dtype: object
# name              Keita Bates-Diop
# mip_prediction            0.202489
# date                    2021-12-16
# Name: 25, dtype: object
# name              Nicolas Batum
# mip_prediction         0.462416
# date                 2021-12-16
# Name: 26, dtype: object
# name              Kent Bazemore
# mip_prediction         0.003095
# date                 2021-12-16
# Name: 27, dtype: object
# name              Darius Bazley
# mip_prediction         0.169093
# date                 2021-12-16
# Name: 28, dtype: object
# name              Bradley Beal
# mip_prediction        0.037103
# date                2021-12-16
# Name: 29, dtype: object
# name              Malik Beasley
# mip_prediction         0.003918
# date                 2021-12-16
# Name: 30, dtype: object
# name              DeAndre' Bembry
# mip_prediction            0.16698
# date                   2021-12-16
# Name: 31, dtype: object
# name              Patrick Beverley
# mip_prediction            0.781051
# date                    2021-12-16
# Name: 32, dtype: object
# name              Saddiq Bey
# mip_prediction      0.615046
# date              2021-12-16
# Name: 33, dtype: object
# name              Khem Birch
# mip_prediction      0.217751
# date              2021-12-16
# Name: 34, dtype: object
# name              Goga Bitadze
# mip_prediction        0.001769
# date                2021-12-16
# Name: 35, dtype: object
# name              Nemanja Bjelica
# mip_prediction           0.132771
# date                   2021-12-16
# Name: 36, dtype: object
# name              Eric Bledsoe
# mip_prediction        0.032504
# date                2021-12-16
# Name: 37, dtype: object
# name                 Bol Bol
# mip_prediction      0.052118
# date              2021-12-16
# Name: 38, dtype: object
# name              Isaac Bonga
# mip_prediction       0.012355
# date               2021-12-16
# Name: 39, dtype: object
# name              Devin Booker
# mip_prediction        0.032504
# date                2021-12-16
# Name: 40, dtype: object
# name              Chris Boucher
# mip_prediction          0.01315
# date                 2021-12-16
# Name: 41, dtype: object
# name              Avery Bradley
# mip_prediction         0.314475
# date                 2021-12-16
# Name: 42, dtype: object
# name              Tony Bradley
# mip_prediction        0.002161
# date                2021-12-16
# Name: 43, dtype: object
# name              Ignas Brazdeikis
# mip_prediction            0.003095
# date                    2021-12-16
# Name: 44, dtype: object
# name              Mikal Bridges
# mip_prediction         0.001937
# date                 2021-12-16
# Name: 45, dtype: object
# name              Miles Bridges
# mip_prediction         0.500018
# date                 2021-12-16
# Name: 46, dtype: object
# name              Oshae Brissett
# mip_prediction          0.002161
# date                  2021-12-16
# Name: 47, dtype: object
# name              Malcolm Brogdon
# mip_prediction            0.13254
# date                   2021-12-16
# Name: 48, dtype: object
# name              Armoni Brooks
# mip_prediction         0.003095
# date                 2021-12-16
# Name: 49, dtype: object
# name              Dillon Brooks
# mip_prediction         0.264617
# date                 2021-12-16
# Name: 50, dtype: object
# name              Bruce Brown
# mip_prediction       0.007571
# date               2021-12-16
# Name: 51, dtype: object
# name              Jaylen Brown
# mip_prediction        0.010019
# date                2021-12-16
# Name: 52, dtype: object
# name              Moses Brown
# mip_prediction       0.003095
# date               2021-12-16
# Name: 53, dtype: object
# name              Sterling Brown
# mip_prediction           0.01315
# date                  2021-12-16
# Name: 54, dtype: object
# name              Troy Brown
# mip_prediction      0.003095
# date              2021-12-16
# Name: 55, dtype: object
# name              Jalen Brunson
# mip_prediction         0.869376
# date                 2021-12-16
# Name: 56, dtype: object
# name              Reggie Bullock
# mip_prediction           0.01315
# date                  2021-12-16
# Name: 57, dtype: object
# name              Trey Burke
# mip_prediction      0.002984
# date              2021-12-16
# Name: 58, dtype: object
# name              Alec Burks
# mip_prediction      0.019494
# date              2021-12-16
# Name: 59, dtype: object
# name              Jimmy Butler
# mip_prediction        0.286443
# date                2021-12-16
# Name: 60, dtype: object
# name              Kentavious Caldwell-Pope
# mip_prediction                    0.322957
# date                            2021-12-16
# Name: 61, dtype: object
# name              Facundo Campazzo
# mip_prediction            0.002984
# date                    2021-12-16
# Name: 62, dtype: object
# name              Clint Capela
# mip_prediction         0.02618
# date                2021-12-16
# Name: 63, dtype: object
# name              Vernon Carey
# mip_prediction        0.003095
# date                2021-12-16
# Name: 64, dtype: object
# name              Jevon Carter
# mip_prediction        0.027916
# date                2021-12-16
# Name: 65, dtype: object
# name              Wendell Carter
# mip_prediction          0.459424
# date                  2021-12-16
# Name: 66, dtype: object
# name              Alex Caruso
# mip_prediction       0.952777
# date               2021-12-16
# Name: 67, dtype: object
# name              Willie Cauley-Stein
# mip_prediction               0.003918
# date                       2021-12-16
# Name: 68, dtype: object
# name              Chris Chiozza
# mip_prediction         0.016055
# date                 2021-12-16
# Name: 69, dtype: object
# name              Brandon Clarke
# mip_prediction          0.010972
# date                  2021-12-16
# Name: 70, dtype: object
# name              Jordan Clarkson
# mip_prediction           0.002984
# date                   2021-12-16
# Name: 71, dtype: object
# name              Nicolas Claxton
# mip_prediction           0.007603
# date                   2021-12-16
# Name: 72, dtype: object
# name              Amir Coffey
# mip_prediction       0.470672
# date               2021-12-16
# Name: 73, dtype: object
# name              John Collins
# mip_prediction        0.040643
# date                2021-12-16
# Name: 74, dtype: object
# name              Mike Conley
# mip_prediction       0.002984
# date               2021-12-16
# Name: 75, dtype: object
# name              Pat Connaughton
# mip_prediction           0.668505
# date                   2021-12-16
# Name: 76, dtype: object
# name              Tyler Cook
# mip_prediction      0.639348
# date              2021-12-16
# Name: 77, dtype: object
# name              Robert Covington
# mip_prediction            0.010039
# date                    2021-12-16
# Name: 78, dtype: object
# name              Torrey Craig
# mip_prediction        0.621539
# date                2021-12-16
# Name: 79, dtype: object
# name              Jae Crowder
# mip_prediction       0.018163
# date               2021-12-16
# Name: 80, dtype: object
# name              Jarrett Culver
# mip_prediction          0.007768
# date                  2021-12-16
# Name: 81, dtype: object
# name              Seth Curry
# mip_prediction      0.256663
# date              2021-12-16
# Name: 82, dtype: object
# name              Stephen Curry
# mip_prediction          0.11358
# date                 2021-12-16
# Name: 83, dtype: object
# name              Anthony Davis
# mip_prediction         0.283364
# date                 2021-12-16
# Name: 84, dtype: object
# name                Ed Davis
# mip_prediction      0.226301
# date              2021-12-16
# Name: 85, dtype: object
# name              Terence Davis
# mip_prediction         0.003095
# date                 2021-12-16
# Name: 86, dtype: object
# name              DeMar DeRozan
# mip_prediction         0.320123
# date                 2021-12-16
# Name: 87, dtype: object
# name              Gabriel Deck
# mip_prediction         0.01015
# date                2021-12-16
# Name: 88, dtype: object
# name              Dewayne Dedmon
# mip_prediction          0.002984
# date                  2021-12-16
# Name: 89, dtype: object
# name              Hamidou Diallo
# mip_prediction           0.01015
# date                  2021-12-16
# Name: 90, dtype: object
# name              Gorgui Dieng
# mip_prediction        0.024123
# date                2021-12-16
# Name: 91, dtype: object
# name              Spencer Dinwiddie
# mip_prediction             0.297936
# date                     2021-12-16
# Name: 92, dtype: object
# name              Luguentz Dort
# mip_prediction         0.450903
# date                 2021-12-16
# Name: 93, dtype: object
# name              Devon Dotson
# mip_prediction        0.442406
# date                2021-12-16
# Name: 94, dtype: object
# name              Sekou Doumbouya
# mip_prediction           0.297275
# date                   2021-12-16
# Name: 95, dtype: object
# name               PJ Dozier
# mip_prediction      0.004012
# date              2021-12-16
# Name: 96, dtype: object
# name              Andre Drummond
# mip_prediction          0.174435
# date                  2021-12-16
# Name: 97, dtype: object
# name              Kevin Durant
# mip_prediction        0.130107
# date                2021-12-16
# Name: 98, dtype: object
# name              Anthony Edwards
# mip_prediction           0.742133
# date                   2021-12-16
# Name: 99, dtype: object
# name               CJ Elleby
# mip_prediction      0.043859
# date              2021-12-16
# Name: 100, dtype: object
# name              Wayne Ellington
# mip_prediction           0.028761
# date                   2021-12-16
# Name: 101, dtype: object
# name              Joel Embiid
# mip_prediction       0.020659
# date               2021-12-16
# Name: 102, dtype: object
# name              Drew Eubanks
# mip_prediction        0.662692
# date                2021-12-16
# Name: 103, dtype: object
# name              Tacko Fall
# mip_prediction      0.003095
# date              2021-12-16
# Name: 104, dtype: object
# name              Derrick Favors
# mip_prediction          0.272955
# date                  2021-12-16
# Name: 105, dtype: object
# name              Bruno Fernando
# mip_prediction          0.003095
# date                  2021-12-16
# Name: 106, dtype: object
# name              Dorian Finney-Smith
# mip_prediction               0.007571
# date                       2021-12-16
# Name: 107, dtype: object
# name              Malik Fitts
# mip_prediction       0.010039
# date               2021-12-16
# Name: 108, dtype: object
# name              Malachi Flynn
# mip_prediction         0.003095
# date                 2021-12-16
# Name: 109, dtype: object
# name              Bryn Forbes
# mip_prediction       0.002984
# date               2021-12-16
# Name: 110, dtype: object
# name              Trent Forrest
# mip_prediction         0.003095
# date                 2021-12-16
# Name: 111, dtype: object
# name              Evan Fournier
# mip_prediction         0.171321
# date                 2021-12-16
# Name: 112, dtype: object
# name              De'Aaron Fox
# mip_prediction        0.011067
# date                2021-12-16
# Name: 113, dtype: object
# name              Daniel Gafford
# mip_prediction          0.591922
# date                  2021-12-16
# Name: 114, dtype: object
# name              Danilo Gallinari
# mip_prediction            0.003918
# date                    2021-12-16
# Name: 115, dtype: object
# name              Darius Garland
# mip_prediction          0.279323
# date                  2021-12-16
# Name: 116, dtype: object
# name                Rudy Gay
# mip_prediction       0.45561
# date              2021-12-16
# Name: 117, dtype: object
# name              Paul George
# mip_prediction       0.404916
# date               2021-12-16
# Name: 118, dtype: object
# name              Taj Gibson
# mip_prediction      0.006834
# date              2021-12-16
# Name: 119, dtype: object
# name              Shai Gilgeous-Alexander
# mip_prediction                   0.013237
# date                           2021-12-16
# Name: 120, dtype: object
# name              Anthony Gill
# mip_prediction        0.160238
# date                2021-12-16
# Name: 121, dtype: object
# name              Rudy Gobert
# mip_prediction       0.280765
# date               2021-12-16
# Name: 122, dtype: object
# name              Aaron Gordon
# mip_prediction        0.261581
# date                2021-12-16
# Name: 123, dtype: object
# name              Eric Gordon
# mip_prediction       0.018163
# date               2021-12-16
# Name: 124, dtype: object
# name              Devonte' Graham
# mip_prediction           0.027405
# date                   2021-12-16
# Name: 125, dtype: object
# name              Jerami Grant
# mip_prediction        0.015654
# date                2021-12-16
# Name: 126, dtype: object
# name              Danny Green
# mip_prediction       0.014626
# date               2021-12-16
# Name: 127, dtype: object
# name              Draymond Green
# mip_prediction          0.261217
# date                  2021-12-16
# Name: 128, dtype: object
# name              JaMychal Green
# mip_prediction          0.011421
# date                  2021-12-16
# Name: 129, dtype: object
# name              Javonte Green
# mip_prediction         0.274093
# date                 2021-12-16
# Name: 130, dtype: object
# name              Jeff Green
# mip_prediction      0.010039
# date              2021-12-16
# Name: 131, dtype: object
# name              Josh Green
# mip_prediction      0.003095
# date              2021-12-16
# Name: 132, dtype: object
# name              Blake Griffin
# mip_prediction         0.015298
# date                 2021-12-16
# Name: 133, dtype: object
# name              Tyrese Haliburton
# mip_prediction             0.013237
# date                     2021-12-16
# Name: 134, dtype: object
# name              R.J. Hampton
# mip_prediction        0.370092
# date                2021-12-16
# Name: 135, dtype: object
# name              Tim Hardaway
# mip_prediction        0.064281
# date                2021-12-16
# Name: 136, dtype: object
# name              James Harden
# mip_prediction        0.015654
# date                2021-12-16
# Name: 137, dtype: object
# name              Maurice Harkless
# mip_prediction            0.172025
# date                    2021-12-16
# Name: 138, dtype: object
# name              Montrezl Harrell
# mip_prediction            0.635225
# date                    2021-12-16
# Name: 139, dtype: object
# name              Gary Harris
# mip_prediction       0.002984
# date               2021-12-16
# Name: 140, dtype: object
# name              Joe Harris
# mip_prediction      0.450684
# date              2021-12-16
# Name: 141, dtype: object
# name              Tobias Harris
# mip_prediction         0.454831
# date                 2021-12-16
# Name: 142, dtype: object
# name               Josh Hart
# mip_prediction      0.636756
# date              2021-12-16
# Name: 143, dtype: object
# name              Isaiah Hartenstein
# mip_prediction              0.666906
# date                      2021-12-16
# Name: 144, dtype: object
# name              Udonis Haslem
# mip_prediction         0.023278
# date                 2021-12-16
# Name: 145, dtype: object
# name              Jaxson Hayes
# mip_prediction        0.009216
# date                2021-12-16
# Name: 146, dtype: object
# name              Killian Hayes
# mip_prediction          0.02694
# date                 2021-12-16
# Name: 147, dtype: object
# name              Gordon Hayward
# mip_prediction          0.002984
# date                  2021-12-16
# Name: 148, dtype: object
# name              Tyler Herro
# mip_prediction        0.45772
# date               2021-12-16
# Name: 149, dtype: object
# name              Buddy Hield
# mip_prediction       0.114887
# date               2021-12-16
# Name: 150, dtype: object
# name              George Hill
# mip_prediction       0.040883
# date               2021-12-16
# Name: 151, dtype: object
# name              Solomon Hill
# mip_prediction        0.007768
# date                2021-12-16
# Name: 152, dtype: object
# name              Aaron Holiday
# mip_prediction         0.027916
# date                 2021-12-16
# Name: 153, dtype: object
# name              Jrue Holiday
# mip_prediction        0.004012
# date                2021-12-16
# Name: 154, dtype: object
# name              Justin Holiday
# mip_prediction          0.005787
# date                  2021-12-16
# Name: 155, dtype: object
# name              Richaun Holmes
# mip_prediction          0.351652
# date                  2021-12-16
# Name: 156, dtype: object
# name              Rodney Hood
# mip_prediction       0.015298
# date               2021-12-16
# Name: 157, dtype: object
# name              Al Horford
# mip_prediction      0.027916
# date              2021-12-16
# Name: 158, dtype: object
# name              Talen Horton-Tucker
# mip_prediction               0.147399
# date                       2021-12-16
# Name: 159, dtype: object
# name              Danuel House
# mip_prediction        0.002161
# date                2021-12-16
# Name: 160, dtype: object
# name              Dwight Howard
# mip_prediction          0.14556
# date                 2021-12-16
# Name: 161, dtype: object
# name              Markus Howard
# mip_prediction          0.14556
# date                 2021-12-16
# Name: 162, dtype: object
# name              Kevin Huerter
# mip_prediction          0.00865
# date                 2021-12-16
# Name: 163, dtype: object
# name              Elijah Hughes
# mip_prediction         0.003095
# date                 2021-12-16
# Name: 164, dtype: object
# name              De'Andre Hunter
# mip_prediction           0.002161
# date                   2021-12-16
# Name: 165, dtype: object
# name              Chandler Hutchison
# mip_prediction              0.002161
# date                      2021-12-16
# Name: 166, dtype: object
# name              Serge Ibaka
# mip_prediction       0.155615
# date               2021-12-16
# Name: 167, dtype: object
# name              Andre Iguodala
# mip_prediction          0.028204
# date                  2021-12-16
# Name: 168, dtype: object
# name              Joe Ingles
# mip_prediction      0.003918
# date              2021-12-16
# Name: 169, dtype: object
# name              Brandon Ingram
# mip_prediction           0.00865
# date                  2021-12-16
# Name: 170, dtype: object
# name              Frank Jackson
# mip_prediction         0.006524
# date                 2021-12-16
# Name: 171, dtype: object
# name              Jaren Jackson
# mip_prediction         0.504065
# date                 2021-12-16
# Name: 172, dtype: object
# name              Josh Jackson
# mip_prediction        0.003918
# date                2021-12-16
# Name: 173, dtype: object
# name              Reggie Jackson
# mip_prediction          0.549555
# date                  2021-12-16
# Name: 174, dtype: object
# name              LeBron James
# mip_prediction        0.006524
# date                2021-12-16
# Name: 175, dtype: object
# name               Ty Jerome
# mip_prediction      0.002703
# date              2021-12-16
# Name: 176, dtype: object
# name              Isaiah Joe
# mip_prediction      0.386639
# date              2021-12-16
# Name: 177, dtype: object
# name              Alize Johnson
# mip_prediction         0.002984
# date                 2021-12-16
# Name: 178, dtype: object
# name              Cameron Johnson
# mip_prediction           0.018163
# date                   2021-12-16
# Name: 179, dtype: object
# name              James Johnson
# mip_prediction          0.01066
# date                 2021-12-16
# Name: 180, dtype: object
# name              Keldon Johnson
# mip_prediction          0.422586
# date                  2021-12-16
# Name: 181, dtype: object
# name              Damian Jones
# mip_prediction        0.015298
# date                2021-12-16
# Name: 182, dtype: object
# name              Derrick Jones
# mip_prediction         0.173825
# date                 2021-12-16
# Name: 183, dtype: object
# name               Tre Jones
# mip_prediction      0.219498
# date              2021-12-16
# Name: 184, dtype: object
# name              Tyus Jones
# mip_prediction      0.007603
# date              2021-12-16
# Name: 185, dtype: object
# name              DeAndre Jordan
# mip_prediction          0.003095
# date                  2021-12-16
# Name: 186, dtype: object
# name              Cory Joseph
# mip_prediction       0.006834
# date               2021-12-16
# Name: 187, dtype: object
# name              Frank Kaminsky
# mip_prediction          0.378464
# date                  2021-12-16
# Name: 188, dtype: object
# name              Luke Kennard
# mip_prediction        0.633912
# date                2021-12-16
# Name: 189, dtype: object
# name              Maxi Kleber
# mip_prediction       0.032043
# date               2021-12-16
# Name: 190, dtype: object
# name              Nathan Knight
# mip_prediction         0.021593
# date                 2021-12-16
# Name: 191, dtype: object
# name              Kevin Knox
# mip_prediction      0.002984
# date              2021-12-16
# Name: 192, dtype: object
# name              John Konchar
# mip_prediction         0.00865
# date                2021-12-16
# Name: 193, dtype: object
# name              Furkan Korkmaz
# mip_prediction          0.477103
# date                  2021-12-16
# Name: 194, dtype: object
# name              Kyle Kuzma
# mip_prediction      0.202022
# date              2021-12-16
# Name: 195, dtype: object
# name              Zach LaVine
# mip_prediction       0.007603
# date               2021-12-16
# Name: 196, dtype: object
# name              Jeremy Lamb
# mip_prediction       0.002984
# date               2021-12-16
# Name: 197, dtype: object
# name              Romeo Langford
# mip_prediction          0.314423
# date                  2021-12-16
# Name: 198, dtype: object
# name              Jake Layman
# mip_prediction       0.003095
# date               2021-12-16
# Name: 199, dtype: object
# name              Caris LeVert
# mip_prediction        0.010972
# date                2021-12-16
# Name: 200, dtype: object
# name              Damion Lee
# mip_prediction      0.495138
# date              2021-12-16
# Name: 201, dtype: object
# name               Saben Lee
# mip_prediction      0.002703
# date              2021-12-16
# Name: 202, dtype: object
# name                Alex Len
# mip_prediction      0.554882
# date              2021-12-16
# Name: 203, dtype: object
# name              Kira Lewis
# mip_prediction       0.00865
# date              2021-12-16
# Name: 204, dtype: object
# name              Damian Lillard
# mip_prediction          0.150719
# date                  2021-12-16
# Name: 205, dtype: object
# name              Nassir Little
# mip_prediction         0.153995
# date                 2021-12-16
# Name: 206, dtype: object
# name              Kevon Looney
# mip_prediction        0.316145
# date                2021-12-16
# Name: 207, dtype: object
# name              Brook Lopez
# mip_prediction       0.171226
# date               2021-12-16
# Name: 208, dtype: object
# name              Robin Lopez
# mip_prediction       0.014907
# date               2021-12-16
# Name: 209, dtype: object
# name              Marcos Louzada Silva
# mip_prediction                0.035816
# date                        2021-12-16
# Name: 210, dtype: object
# name              Kevin Love
# mip_prediction      0.015298
# date              2021-12-16
# Name: 211, dtype: object
# name              Kyle Lowry
# mip_prediction      0.154279
# date              2021-12-16
# Name: 212, dtype: object
# name              Trey Lyles
# mip_prediction      0.761933
# date              2021-12-16
# Name: 213, dtype: object
# name              Terance Mann
# mip_prediction        0.548068
# date                2021-12-16
# Name: 214, dtype: object
# name              Lauri Markkanen
# mip_prediction           0.115797
# date                   2021-12-16
# Name: 215, dtype: object
# name              Naji Marshall
# mip_prediction         0.002161
# date                 2021-12-16
# Name: 216, dtype: object
# name              Caleb Martin
# mip_prediction        0.514542
# date                2021-12-16
# Name: 217, dtype: object
# name              Cody Martin
# mip_prediction       0.774756
# date               2021-12-16
# Name: 218, dtype: object
# name              Kelan Martin
# mip_prediction        0.593871
# date                2021-12-16
# Name: 219, dtype: object
# name              Kenyon Martin
# mip_prediction         0.003918
# date                 2021-12-16
# Name: 220, dtype: object
# name              Garrison Mathews
# mip_prediction             0.17862
# date                    2021-12-16
# Name: 221, dtype: object
# name              Tyrese Maxey
# mip_prediction         0.25181
# date                2021-12-16
# Name: 222, dtype: object
# name              Skylar Mays
# mip_prediction       0.002161
# date               2021-12-16
# Name: 223, dtype: object
# name              CJ McCollum
# mip_prediction       0.013237
# date               2021-12-16
# Name: 224, dtype: object
# name              T.J. McConnell
# mip_prediction          0.112027
# date                  2021-12-16
# Name: 225, dtype: object
# name              Jaden McDaniels
# mip_prediction           0.013237
# date                   2021-12-16
# Name: 226, dtype: object
# name              Jalen McDaniels
# mip_prediction           0.003918
# date                   2021-12-16
# Name: 227, dtype: object
# name              Doug McDermott
# mip_prediction          0.002984
# date                  2021-12-16
# Name: 228, dtype: object
# name              JaVale McGee
# mip_prediction        0.386534
# date                2021-12-16
# Name: 229, dtype: object
# name              Rodney McGruder
# mip_prediction           0.003095
# date                   2021-12-16
# Name: 230, dtype: object
# name              Jordan McLaughlin
# mip_prediction              0.01315
# date                     2021-12-16
# Name: 231, dtype: object
# name              Ben McLemore
# mip_prediction        0.002161
# date                2021-12-16
# Name: 232, dtype: object
# name              De'Anthony Melton
# mip_prediction             0.294027
# date                     2021-12-16
# Name: 233, dtype: object
# name              Sam Merrill
# mip_prediction       0.399065
# date               2021-12-16
# Name: 234, dtype: object
# name              Chimezie Metu
# mip_prediction         0.217959
# date                 2021-12-16
# Name: 235, dtype: object
# name              Khris Middleton
# mip_prediction           0.007571
# date                   2021-12-16
# Name: 236, dtype: object
# name              Patty Mills
# mip_prediction       0.358844
# date               2021-12-16
# Name: 237, dtype: object
# name              Paul Millsap
# mip_prediction        0.003095
# date                2021-12-16
# Name: 238, dtype: object
# name              Shake Milton
# mip_prediction        0.027916
# date                2021-12-16
# Name: 239, dtype: object
# name              Donovan Mitchell
# mip_prediction            0.008599
# date                    2021-12-16
# Name: 240, dtype: object
# name              Malik Monk
# mip_prediction      0.132668
# date              2021-12-16
# Name: 241, dtype: object
# name               Ja Morant
# mip_prediction      0.303147
# date              2021-12-16
# Name: 242, dtype: object
# name              Marcus Morris
# mip_prediction         0.144626
# date                 2021-12-16
# Name: 243, dtype: object
# name              Markieff Morris
# mip_prediction           0.371539
# date                   2021-12-16
# Name: 244, dtype: object
# name              Monte Morris
# mip_prediction        0.472149
# date                2021-12-16
# Name: 245, dtype: object
# name              Mychal Mulder
# mip_prediction         0.022113
# date                 2021-12-16
# Name: 246, dtype: object
# name              Dejounte Murray
# mip_prediction           0.818459
# date                   2021-12-16
# Name: 247, dtype: object
# name              Mike Muscala
# mip_prediction        0.312758
# date                2021-12-16
# Name: 248, dtype: object
# name              Svi Mykhailiuk
# mip_prediction           0.01066
# date                  2021-12-16
# Name: 249, dtype: object
# name              Abdel Nader
# mip_prediction       0.007571
# date               2021-12-16
# Name: 250, dtype: object
# name              Larry Nance
# mip_prediction       0.003095
# date               2021-12-16
# Name: 251, dtype: object
# name              Aaron Nesmith
# mip_prediction         0.002984
# date                 2021-12-16
# Name: 252, dtype: object
# name               Raul Neto
# mip_prediction      0.006834
# date              2021-12-16
# Name: 253, dtype: object
# name              Georges Niang
# mip_prediction         0.974458
# date                 2021-12-16
# Name: 254, dtype: object
# name              Zeke Nnaji
# mip_prediction      0.347938
# date              2021-12-16
# Name: 255, dtype: object
# name              Nerlens Noel
# mip_prediction        0.062559
# date                2021-12-16
# Name: 256, dtype: object
# name              Jaylen Nowell
# mip_prediction         0.003918
# date                 2021-12-16
# Name: 257, dtype: object
# name              Frank Ntilikina
# mip_prediction           0.274093
# date                   2021-12-16
# Name: 258, dtype: object
# name              David Nwaba
# mip_prediction       0.002984
# date               2021-12-16
# Name: 259, dtype: object
# name              Jordan Nwora
# mip_prediction        0.355312
# date                2021-12-16
# Name: 260, dtype: object
# name              Royce O'Neale
# mip_prediction         0.211964
# date                 2021-12-16
# Name: 261, dtype: object
# name              Semi Ojeleye
# mip_prediction        0.013237
# date                2021-12-16
# Name: 262, dtype: object
# name              Chuma Okeke
# mip_prediction       0.430713
# date               2021-12-16
# Name: 263, dtype: object
# name              Josh Okogie
# mip_prediction        0.00865
# date               2021-12-16
# Name: 264, dtype: object
# name              Isaac Okoro
# mip_prediction       0.218849
# date               2021-12-16
# Name: 265, dtype: object
# name               KZ Okpala
# mip_prediction      0.003095
# date              2021-12-16
# Name: 266, dtype: object
# name              Kelly Olynyk
# mip_prediction        0.007571
# date                2021-12-16
# Name: 267, dtype: object
# name                Miye Oni
# mip_prediction      0.003095
# date              2021-12-16
# Name: 268, dtype: object
# name              Cedi Osman
# mip_prediction      0.681943
# date              2021-12-16
# Name: 269, dtype: object
# name              Kelly Oubre
# mip_prediction       0.002984
# date               2021-12-16
# Name: 270, dtype: object
# name              Jabari Parker
# mip_prediction         0.006524
# date                 2021-12-16
# Name: 271, dtype: object
# name              Eric Paschall
# mip_prediction         0.010972
# date                 2021-12-16
# Name: 272, dtype: object
# name              Chris Paul
# mip_prediction      0.025246
# date              2021-12-16
# Name: 273, dtype: object
# name              Cameron Payne
# mip_prediction         0.255526
# date                 2021-12-16
# Name: 274, dtype: object
# name              Elfrid Payton
# mip_prediction         0.013973
# date                 2021-12-16
# Name: 275, dtype: object
# name              Gary Payton
# mip_prediction       0.294328
# date               2021-12-16
# Name: 276, dtype: object
# name              Mason Plumlee
# mip_prediction          0.01556
# date                 2021-12-16
# Name: 277, dtype: object
# name              Jakob Poeltl
# mip_prediction        0.322879
# date                2021-12-16
# Name: 278, dtype: object
# name              Aleksej Pokusevski
# mip_prediction              0.003918
# date                      2021-12-16
# Name: 279, dtype: object
# name              Jordan Poole
# mip_prediction        0.185306
# date                2021-12-16
# Name: 280, dtype: object
# name              Kevin Porter
# mip_prediction        0.013237
# date                2021-12-16
# Name: 281, dtype: object
# name              Michael Porter
# mip_prediction          0.025246
# date                  2021-12-16
# Name: 282, dtype: object
# name              Otto Porter
# mip_prediction       0.155615
# date               2021-12-16
# Name: 283, dtype: object
# name              Bobby Portis
# mip_prediction        0.513281
# date                2021-12-16
# Name: 284, dtype: object
# name              Dwight Powell
# mip_prediction         0.423031
# date                 2021-12-16
# Name: 285, dtype: object
# name              Norman Powell
# mip_prediction         0.002984
# date                 2021-12-16
# Name: 286, dtype: object
# name              Taurean Prince
# mip_prediction          0.003095
# date                  2021-12-16
# Name: 287, dtype: object
# name              Payton Pritchard
# mip_prediction            0.002984
# date                    2021-12-16
# Name: 288, dtype: object
# name              Immanuel Quickley
# mip_prediction             0.011421
# date                     2021-12-16
# Name: 289, dtype: object
# name              Jahmi'us Ramsey
# mip_prediction           0.003918
# date                   2021-12-16
# Name: 290, dtype: object
# name              Julius Randle
# mip_prediction         0.013576
# date                 2021-12-16
# Name: 291, dtype: object
# name              Cam Reddish
# mip_prediction        0.50674
# date               2021-12-16
# Name: 292, dtype: object
# name               Paul Reed
# mip_prediction       0.04169
# date              2021-12-16
# Name: 293, dtype: object
# name                Naz Reid
# mip_prediction       0.01556
# date              2021-12-16
# Name: 294, dtype: object
# name              Nick Richards
# mip_prediction         0.358256
# date                 2021-12-16
# Name: 295, dtype: object
# name              Josh Richardson
# mip_prediction            0.16698
# date                   2021-12-16
# Name: 296, dtype: object
# name              Austin Rivers
# mip_prediction         0.003095
# date                 2021-12-16
# Name: 297, dtype: object
# name              Duncan Robinson
# mip_prediction           0.020292
# date                   2021-12-16
# Name: 298, dtype: object
# name              Justin Robinson
# mip_prediction           0.510672
# date                   2021-12-16
# Name: 299, dtype: object
# name              Mitchell Robinson
# mip_prediction             0.163516
# date                     2021-12-16
# Name: 300, dtype: object
# name              Isaiah Roby
# mip_prediction       0.003095
# date               2021-12-16
# Name: 301, dtype: object
# name              Rajon Rondo
# mip_prediction       0.002984
# date               2021-12-16
# Name: 302, dtype: object
# name              Derrick Rose
# mip_prediction         0.00865
# date                2021-12-16
# Name: 303, dtype: object
# name              Terrence Ross
# mip_prediction         0.002984
# date                 2021-12-16
# Name: 304, dtype: object
# name              Terry Rozier
# mip_prediction        0.010039
# date                2021-12-16
# Name: 305, dtype: object
# name              Ricky Rubio
# mip_prediction       0.869788
# date               2021-12-16
# Name: 306, dtype: object
# name              D'Angelo Russell
# mip_prediction            0.026869
# date                    2021-12-16
# Name: 307, dtype: object
# name              Domantas Sabonis
# mip_prediction            0.002984
# date                    2021-12-16
# Name: 308, dtype: object
# name              Jay Scrubb
# mip_prediction      0.007768
# date              2021-12-16
# Name: 309, dtype: object
# name              Collin Sexton
# mip_prediction         0.022113
# date                 2021-12-16
# Name: 310, dtype: object
# name              Landry Shamet
# mip_prediction         0.130259
# date                 2021-12-16
# Name: 311, dtype: object
# name              Pascal Siakam
# mip_prediction         0.010039
# date                 2021-12-16
# Name: 312, dtype: object
# name              Anfernee Simons
# mip_prediction           0.659047
# date                   2021-12-16
# Name: 313, dtype: object
# name              Marcus Smart
# mip_prediction        0.128198
# date                2021-12-16
# Name: 314, dtype: object
# name              Dennis Smith
# mip_prediction        0.007571
# date                2021-12-16
# Name: 315, dtype: object
# name               Ish Smith
# mip_prediction      0.002984
# date              2021-12-16
# Name: 316, dtype: object
# name              Jalen Smith
# mip_prediction       0.489925
# date               2021-12-16
# Name: 317, dtype: object
# name              Tony Snell
# mip_prediction      0.003095
# date              2021-12-16
# Name: 318, dtype: object
# name              Lamar Stevens
# mip_prediction         0.003095
# date                 2021-12-16
# Name: 319, dtype: object
# name              Isaiah Stewart
# mip_prediction          0.037103
# date                  2021-12-16
# Name: 320, dtype: object
# name               Max Strus
# mip_prediction      0.340982
# date              2021-12-16
# Name: 321, dtype: object
# name              Jae'Sean Tate
# mip_prediction         0.014658
# date                 2021-12-16
# Name: 322, dtype: object
# name              Jayson Tatum
# mip_prediction        0.007603
# date                2021-12-16
# Name: 323, dtype: object
# name              Garrett Temple
# mip_prediction          0.011067
# date                  2021-12-16
# Name: 324, dtype: object
# name              Daniel Theis
# mip_prediction        0.002161
# date                2021-12-16
# Name: 325, dtype: object
# name              Brodric Thomas
# mip_prediction           0.01315
# date                  2021-12-16
# Name: 326, dtype: object
# name              Matt Thomas
# mip_prediction       0.002703
# date               2021-12-16
# Name: 327, dtype: object
# name              Tristan Thompson
# mip_prediction            0.003095
# date                    2021-12-16
# Name: 328, dtype: object
# name              Matisse Thybulle
# mip_prediction            1.210526
# date                    2021-12-16
# Name: 329, dtype: object
# name              Killian Tillie
# mip_prediction          0.001769
# date                  2021-12-16
# Name: 330, dtype: object
# name              Xavier Tillman
# mip_prediction          0.008505
# date                  2021-12-16
# Name: 331, dtype: object
# name              Obi Toppin
# mip_prediction      0.393642
# date              2021-12-16
# Name: 332, dtype: object
# name              Juan Toscano-Anderson
# mip_prediction                 0.010039
# date                         2021-12-16
# Name: 333, dtype: object
# name              Karl-Anthony Towns
# mip_prediction              0.014626
# date                      2021-12-16
# Name: 334, dtype: object
# name              Gary Trent
# mip_prediction      0.665552
# date              2021-12-16
# Name: 335, dtype: object
# name              P.J. Tucker
# mip_prediction       0.411766
# date               2021-12-16
# Name: 336, dtype: object
# name              Myles Turner
# mip_prediction        0.138231
# date                2021-12-16
# Name: 337, dtype: object
# name              Denzel Valentine
# mip_prediction            0.003095
# date                    2021-12-16
# Name: 338, dtype: object
# name              Fred VanVleet
# mip_prediction         0.138231
# date                 2021-12-16
# Name: 339, dtype: object
# name              Jarred Vanderbilt
# mip_prediction             0.613922
# date                     2021-12-16
# Name: 340, dtype: object
# name              Devin Vassell
# mip_prediction         0.904178
# date                 2021-12-16
# Name: 341, dtype: object
# name              Gabe Vincent
# mip_prediction        0.056586
# date                2021-12-16
# Name: 342, dtype: object
# name               Dean Wade
# mip_prediction      0.019097
# date              2021-12-16
# Name: 343, dtype: object
# name              Moritz Wagner
# mip_prediction         0.002161
# date                 2021-12-16
# Name: 344, dtype: object
# name              Kemba Walker
# mip_prediction        0.010972
# date                2021-12-16
# Name: 345, dtype: object
# name              Lonnie Walker
# mip_prediction         0.112533
# date                 2021-12-16
# Name: 346, dtype: object
# name              Brad Wanamaker
# mip_prediction           0.00865
# date                  2021-12-16
# Name: 347, dtype: object
# name              P.J. Washington
# mip_prediction           0.003095
# date                   2021-12-16
# Name: 348, dtype: object
# name              Yuta Watanabe
# mip_prediction         0.166587
# date                 2021-12-16
# Name: 349, dtype: object
# name              Russell Westbrook
# mip_prediction             0.002984
# date                     2021-12-16
# Name: 350, dtype: object
# name              Coby White
# mip_prediction      0.003095
# date              2021-12-16
# Name: 351, dtype: object
# name              Derrick White
# mip_prediction         0.046616
# date                 2021-12-16
# Name: 352, dtype: object
# name              Hassan Whiteside
# mip_prediction            0.172025
# date                    2021-12-16
# Name: 353, dtype: object
# name              Andrew Wiggins
# mip_prediction          0.257744
# date                  2021-12-16
# Name: 354, dtype: object
# name              Grant Williams
# mip_prediction          0.439887
# date                  2021-12-16
# Name: 355, dtype: object
# name              Kenrich Williams
# mip_prediction            0.013973
# date                    2021-12-16
# Name: 356, dtype: object
# name              Lou Williams
# mip_prediction        0.003095
# date                2021-12-16
# Name: 357, dtype: object
# name              Patrick Williams
# mip_prediction            0.003095
# date                    2021-12-16
# Name: 358, dtype: object
# name              Robert Williams
# mip_prediction           0.159421
# date                   2021-12-16
# Name: 359, dtype: object
# name              Dylan Windler
# mip_prediction         0.007768
# date                 2021-12-16
# Name: 360, dtype: object
# name              Justise Winslow
# mip_prediction           0.002161
# date                   2021-12-16
# Name: 361, dtype: object
# name              Christian Wood
# mip_prediction          0.053046
# date                  2021-12-16
# Name: 362, dtype: object
# name              Robert Woodard
# mip_prediction          0.003095
# date                  2021-12-16
# Name: 363, dtype: object
# name              Delon Wright
# mip_prediction        0.003095
# date                2021-12-16
# Name: 364, dtype: object
# name              Thaddeus Young
# mip_prediction          0.003918
# date                  2021-12-16
# Name: 365, dtype: object
# name              Trae Young
# mip_prediction      0.064539
# date              2021-12-16
# Name: 366, dtype: object
# name              Cody Zeller
# mip_prediction       0.003095
# date               2021-12-16
# Name: 367, dtype: object
# name              Ivica Zubac
# mip_prediction       0.360601
# date               2021-12-16
# Name: 368, dtype: object
#                name mip_prediction        date
# 0  Precious Achiuwa       0.184124  2021-12-16
# 1      Steven Adams       0.020659  2021-12-16
# 2       Bam Adebayo       0.625962  2021-12-16

# %%
#NaiveBayes
#=====your code here==========
from pyspark.ml.classification import NaiveBayes
nbModel_mvp = NaiveBayes(featuresCol="features", labelCol="mvpLabel").fit(trainingData)
nbModel_dpoy = NaiveBayes(featuresCol="features", labelCol="dpoyLabel").fit(trainingData)
#===============================

mvp_predictions = nbModel_mvp.transform(testData)
dpoy_predictions = nbModel_dpoy.transform(testData)

# compute accuracy on the test set
evaluator = MulticlassClassificationEvaluator(labelCol="mvpLabel", predictionCol="prediction", metricName="accuracy")
accuracy = evaluator.evaluate(mvp_predictions)
print("Test set accuracy for mvp prediction = " + str(accuracy))
evaluator = MulticlassClassificationEvaluator(labelCol="dpoyLabel", predictionCol="prediction", metricName="accuracy")
accuracy = evaluator.evaluate(dpoy_predictions)
print("Test set accuracy for dpoy prediction = " + str(accuracy))

mvp_predictions = nbModel_mvp.transform(ongoing_dataset)
mvp_selected = mvp_predictions.select(['name', 'probability', 'prediction', 'blk'])
# mvp_selected.show(mvp_selected.count(), False)

dpoy_predictions = nbModel_dpoy.transform(ongoing_dataset)
dpoy_selected = dpoy_predictions.select(['name', 'probability', 'prediction'])
# dpoy_selected.show(dpoy_selected.count(), False)
print(dpoy_predictions)
# Out:
# Test set accuracy for mvp prediction = 0.9824046920821115
# Test set accuracy for dpoy prediction = 0.9765395894428153
# DataFrame[features: vector, id: string, name: string, reb: double, ast: double, stl: double, blk: double, tov: double, pts: double, rawPrediction: vector, probability: vector, prediction: double]

# %%
#Decision Tree
#=====your code here==========
from pyspark.ml.classification import DecisionTreeClassifier
dtModel_mvp = DecisionTreeClassifier(featuresCol="features", labelCol="mvpLabel").fit(trainingData)
dtModel_dpoy = DecisionTreeClassifier(featuresCol="features", labelCol="dpoyLabel").fit(trainingData)
#===============================

mvp_predictions = dtModel_mvp.transform(testData)
dpoy_predictions = dtModel_dpoy.transform(testData)

# compute accuracy on the test set
evaluator = MulticlassClassificationEvaluator(labelCol="mvpLabel", predictionCol="prediction", metricName="accuracy")
accuracy = evaluator.evaluate(mvp_predictions)
print("Test set accuracy for mvp prediction = " + str(accuracy))
evaluator = MulticlassClassificationEvaluator(labelCol="dpoyLabel", predictionCol="prediction", metricName="accuracy")
accuracy = evaluator.evaluate(dpoy_predictions)
print("Test set accuracy for dpoy prediction = " + str(accuracy))

mvp_predictions = dtModel_mvp.transform(ongoing_dataset)
mvp_selected = mvp_predictions.select(['name', 'probability', 'prediction', 'blk'])
# mvp_selected.show(mvp_selected.count(), False)

dpoy_predictions = dtModel_dpoy.transform(ongoing_dataset)
dpoy_selected = dpoy_predictions.select(['name', 'probability', 'prediction', 'blk'])
# dpoy_selected.show(dpoy_selected.count(), False)
print(dpoy_predictions)
# Out:
# Test set accuracy for mvp prediction = 0.9794721407624634
# Test set accuracy for dpoy prediction = 0.9765395894428153
# DataFrame[features: vector, id: string, name: string, reb: double, ast: double, stl: double, blk: double, tov: double, pts: double, rawPrediction: vector, probability: vector, prediction: double]

# %%
#Gradient Boosting Trees
#=====your code here==========
from pyspark.ml.classification import GBTClassifier
gbtModel_mvp = GBTClassifier(featuresCol="features", labelCol="mvpLabel").fit(trainingData)
gbtModel_dpoy = GBTClassifier(featuresCol="features", labelCol="dpoyLabel").fit(trainingData)
#===============================

mvp_predictions = gbtModel_mvp.transform(testData)
dpoy_predictions = gbtModel_dpoy.transform(testData)

# compute accuracy on the test set
evaluator = MulticlassClassificationEvaluator(labelCol="mvpLabel", predictionCol="prediction", metricName="accuracy")
accuracy = evaluator.evaluate(mvp_predictions)
print("Test set accuracy for mvp prediction = " + str(accuracy))
evaluator = MulticlassClassificationEvaluator(labelCol="dpoyLabel", predictionCol="prediction", metricName="accuracy")
accuracy = evaluator.evaluate(dpoy_predictions)
print("Test set accuracy for dpoy prediction = " + str(accuracy))

mvp_predictions = gbtModel_mvp.transform(ongoing_dataset)
mvp_selected = mvp_predictions.select(['name', 'probability', 'prediction', 'blk'])
# mvp_selected.show(mvp_selected.count(), False)

dpoy_predictions = gbtModel_dpoy.transform(ongoing_dataset)
dpoy_selected = dpoy_predictions.select(['name', 'probability', 'prediction', 'blk'])
# dpoy_selected.show(dpoy_selected.count(), False)
print(dpoy_predictions)
# Out:
# Test set accuracy for mvp prediction = 0.9736070381231672
# Test set accuracy for dpoy prediction = 0.9765395894428153
# DataFrame[features: vector, id: string, name: string, reb: double, ast: double, stl: double, blk: double, tov: double, pts: double, rawPrediction: vector, probability: vector, prediction: double]

# %%
# Multi-layer Perceptron
#=====your code here==========
from pyspark.ml.classification import MultilayerPerceptronClassifier
mlpModel_mvp = MultilayerPerceptronClassifier(layers=[6, 5, 5, 2], seed=123, featuresCol="features", labelCol="mvpLabel").fit(trainingData)
mlpModel_dpoy = MultilayerPerceptronClassifier(layers=[6, 5, 5, 2], seed=123, featuresCol="features", labelCol="dpoyLabel").fit(trainingData)
#===============================

mvp_predictions = mlpModel_mvp.transform(testData)
dpoy_predictions = mlpModel_dpoy.transform(testData)

# compute accuracy on the test set
evaluator = MulticlassClassificationEvaluator(labelCol="mvpLabel", predictionCol="prediction", metricName="accuracy")
accuracy = evaluator.evaluate(mvp_predictions)
print("Test set accuracy for mvp prediction = " + str(accuracy))
evaluator = MulticlassClassificationEvaluator(labelCol="dpoyLabel", predictionCol="prediction", metricName="accuracy")
accuracy = evaluator.evaluate(dpoy_predictions)
print("Test set accuracy for dpoy prediction = " + str(accuracy))

mvp_predictions = mlpModel_mvp.transform(ongoing_dataset)
mvp_selected = mvp_predictions.select(['name', 'probability', 'prediction', 'blk'])
# mvp_selected.show(mvp_selected.count(), False)

dpoy_predictions = mlpModel_dpoy.transform(ongoing_dataset)
dpoy_selected = dpoy_predictions.select(['name', 'probability', 'prediction', 'blk'])
# dpoy_selected.show(dpoy_selected.count(), False)
print(dpoy_predictions)
# Out:
# Test set accuracy for mvp prediction = 0.9912023460410557
# Test set accuracy for dpoy prediction = 0.9706744868035191
# DataFrame[features: vector, id: string, name: string, reb: double, ast: double, stl: double, blk: double, tov: double, pts: double, rawPrediction: vector, probability: vector, prediction: double]

# %%
# Linear Support Vector Machine
#=====your code here==========
from pyspark.ml.classification import LinearSVC
svmModel_mvp = LinearSVC(maxIter=10, regParam=0.1, labelCol="mvpLabel").fit(trainingData)
svmModel_dpoy = LinearSVC(maxIter=10, regParam=0.1, labelCol="dpoyLabel").fit(trainingData)
#===============================

mvp_predictions = svmModel_mvp.transform(testData)
dpoy_predictions = svmModel_dpoy.transform(testData)

# compute accuracy on the test set
evaluator = MulticlassClassificationEvaluator(labelCol="mvpLabel", predictionCol="prediction", metricName="accuracy")
accuracy = evaluator.evaluate(mvp_predictions)
print("Test set accuracy for mvp prediction = " + str(accuracy))
evaluator = MulticlassClassificationEvaluator(labelCol="dpoyLabel", predictionCol="prediction", metricName="accuracy")
accuracy = evaluator.evaluate(dpoy_predictions)
print("Test set accuracy for dpoy prediction = " + str(accuracy))

mvp_predictions = svmModel_mvp.transform(ongoing_dataset)
mvp_selected = mvp_predictions.select(['name', 'prediction', 'blk'])
# mvp_selected.show(mvp_selected.count(), False)

dpoy_predictions = svmModel_dpoy.transform(ongoing_dataset)
dpoy_selected = dpoy_predictions.select(['name', 'prediction', 'blk'])
# dpoy_selected.show(dpoy_selected.count(), False)
print(dpoy_predictions)
# Out:
# Test set accuracy for mvp prediction = 0.9824046920821115
# Test set accuracy for dpoy prediction = 0.9765395894428153
# DataFrame[features: vector, id: string, name: string, reb: double, ast: double, stl: double, blk: double, tov: double, pts: double, rawPrediction: vector, prediction: double]

# %% [markdown]
# 4. Comparison and analysis

# %%
# query to see if there is new request
from google.cloud import bigquery

# %%
df.printSchema()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- label: long (nullable = true)
#  |-- reb: double (nullable = true)
#  |-- ast: double (nullable = true)
#  |-- stl: double (nullable = true)
#  |-- blk: double (nullable = true)
#  |-- tov: double (nullable = true)
#  |-- pts: double (nullable = true)
#  |-- new_request: long (nullable = true)
#  |-- percentage: double (nullable = true)

# %%
####################### data preprocessing #######################
stages = []
# Transform all features into a vector using VectorAssembler
numericCols = ["reb", "ast", "stl", "blk", "tov", "pts"]
assemblerInputs = numericCols
assembler = VectorAssembler(inputCols=assemblerInputs, outputCol="features")
stages += [assembler]
pipeline = Pipeline(stages=stages)
pipelineModel = pipeline.fit(df)
preppedDataDF = pipelineModel.transform(df)
preppedDataDF.take(3)
# Out:
# [Row(id='fa7a753f-e41b-4302-ad17-309a8cc18697', name='Isaiah Thomas', label=0, reb=1.7, ast=3.65, stl=0.325, blk=0.15, tov=1.925, pts=12.2, new_request=1, percentage=0.0, features=DenseVector([1.7, 3.65, 0.325, 0.15, 1.925, 12.2])),
#  Row(id='7c477949-5f36-4580-b607-0de0fb9f9c2d', name='Pascal Siakam', label=1, reb=7.316666667, ast=3.45, stl=1.016666667, blk=0.883333333, tov=2.466666667, pts=22.85, new_request=1, percentage=0.0, features=DenseVector([7.3167, 3.45, 1.0167, 0.8833, 2.4667, 22.85])),
#  Row(id='a7a0fa13-a4b6-43cf-b367-ae9099ccf92e', name='Elfrid Payton', label=0, reb=4.711111111, ast=7.177777778, stl=1.555555556, blk=0.377777778, tov=2.133333333, pts=9.977777778, new_request=1, percentage=0.0, features=DenseVector([4.7111, 7.1778, 1.5556, 0.3778, 2.1333, 9.9778]))]

# %%
models = [lrModel, rfModel, dtModel, nbModel, gbtModel, mlpModel, svmModel, ovrModel]
print(testData)
print(preppedDataDF)
# Out:
# DataFrame[features: vector, id: string, name: string, label: int, reb: double, ast: double, stl: double, blk: double, tov: double, pts: double]
# DataFrame[id: string, name: string, label: bigint, reb: double, ast: double, stl: double, blk: double, tov: double, pts: double, new_request: bigint, percentage: double, features: vector]

# %%
predictions = rfModel.transform(preppedDataDF)
print(predictions)
predictions.show(3)
selected = predictions.select(['name', 'probability', 'prediction', 'pts', 'new_request'])
selected.show(3)
# selected.show(selected.count(), False)

probability = predictions.select(['probability'])
probability.show(3)
# Out:
# DataFrame[id: string, name: string, label: bigint, reb: double, ast: double, stl: double, blk: double, tov: double, pts: double, new_request: bigint, percentage: double, features: vector, rawPrediction: vector, probability: vector, prediction: double]
# +--------------------+-------------+-----+-----------+-----------+-----------+-----------+-----------+-----------+-----------+----------+--------------------+--------------------+--------------------+----------+
# |                  id|         name|label|        reb|        ast|        stl|        blk|        tov|        pts|new_request|percentage|            features|       rawPrediction|         probability|prediction|
# +--------------------+-------------+-----+-----------+-----------+-----------+-----------+-----------+-----------+-----------+----------+--------------------+--------------------+--------------------+----------+
# |fa7a753f-e41b-430...|Isaiah Thomas|    0|        1.7|       3.65|      0.325|       0.15|      1.925|       12.2|          1|       0.0|[1.7,3.65,0.325,0...|[19.9955872903471...|[0.99977936451735...|       0.0|
# |7c477949-5f36-458...|Pascal Siakam|    1|7.316666667|       3.45|1.016666667|0.883333333|2.466666667|      22.85|          1|       0.0|[7.316666667,3.45...|[9.16225395701378...|[0.45811269785068...|       1.0|
# |a7a0fa13-a4b6-43c...|Elfrid Payton|    0|4.711111111|7.177777778|1.555555556|0.377777778|2.133333333|9.977777778|          1|       0.0|[4.711111111,7.17...|[17.2800167511703...|[0.86400083755851...|       0.0|
# +--------------------+-------------+-----+-----------+-----------+-----------+-----------+-----------+-----------+-----------+----------+--------------------+--------------------+--------------------+----------+
# only showing top 3 rows
#
# +-------------+--------------------+----------+-----------+-----------+
# |         name|         probability|prediction|        pts|new_request|
# +-------------+--------------------+----------+-----------+-----------+
# |Isaiah Thomas|[0.99977936451735...|       0.0|       12.2|          1|
# |Pascal Siakam|[0.45811269785068...|       1.0|      22.85|          1|
# |Elfrid Payton|[0.86400083755851...|       0.0|9.977777778|          1|
# +-------------+--------------------+----------+-----------+-----------+
# only showing top 3 rows
#
# +--------------------+
# |         probability|
# +--------------------+
# |[0.99977936451735...|
# |[0.45811269785068...|
# |[0.86400083755851...|
# +--------------------+
# only showing top 3 rows
